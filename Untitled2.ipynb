# %%
import numpy as np
import numpy.linalg as la
import matplotlib.pyplot as plt
from pydlm import dlm, autoReg
from pydlm import modelTuner
from EDMtoolkit import *
from modelSystems import *

# %matplotlib notebook
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
x0 = np.array([0.70])
tlen = 256

r = lambda t : 3.6

Xr = generateTimeSeriesDiscrete(Logistic, x0, nsargs=(r,), tlen=256, settlingTime=10)

# %%
plt.plot(Xr[:-1])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
lDLM = dlm(Xr.flatten()) + autoReg(discount=0.7,degree=4)

# %%
tuner = modelTuner(method="gradient_descent", loss="mse")

lDLM = tuner.tune(lDLM, maxit=1000)
tuner.getDiscounts()
# Out:
# Initializing models...
# Initialization finished.
# The algorithm stops without converging.
# It might require more step to converge. Use tune(..., maixt = <a larger number>) instead.
# [0.7999999999999889]

# %%
lDLM.fit()

# %%
lDLM.getMSE()
# Out:
# 0.46616319940088935

# %%
residual = lDLM.getResidual()

plt.plot(residual)

plt.show()

# %%
residual
# Out:
# [0.32823811268569597,
#  0.7937922746384221,
#  0.5892699577060152,
#  0.8713111487441987,
#  0.40366091094574885,
#  0.8665876077127094,
#  0.41620869313730174,
#  0.8747244608192682,
#  0.3944936824693513,
#  0.8599263010600391,
#  0.4336310080988572,
#  0.8841425648904937,
#  0.36876416342167023,
#  0.8379977587113092,
#  0.4887270543820738,
#  0.8995425145095429,
#  0.32531680475781005,
#  0.7901488126799242,
#  0.596929199401549,
#  0.8661770290921491,
#  0.4172917801148906,
#  0.8753736613083711,
#  0.3927406118254138,
#  0.8585835251342884,
#  0.43710427980816186,
#  0.8857588621735799,
#  0.3642843609163619,
#  0.8336925551092308,
#  0.4991374031928227,
#  0.8999973213362938,
#  0.3240077145256429,
#  0.7884961756326447,
#  0.6003718439232175,
#  0.8637317746108317,
#  0.4237171060984384,
#  0.8790513123528111,
#  0.38275236937300194,
#  0.8505107752044782,
#  0.4577119072760008,
#  0.8935621819695594,
#  0.3423917121240939,
#  0.8105746593341718,
#  0.5527561715260673,
#  0.8899804309172838,
#  0.35249494860565056,
#  0.8216721353273412,
#  0.5274973344742153,
#  0.8972780277485273,
#  0.3318126072056654,
#  0.7981668032581591,
#  0.5799476067653168,
#  0.8769901686209939,
#  0.38836228594721256,
#  0.855133274883845,
#  0.4459692854529913,
#  0.8894904547879429,
#  0.3538698682646932,
#  0.8231255445564788,
#  0.5241235768382845,
#  0.8979049909458986,
#  0.3300178254492397,
#  0.7959818172059815,
#  0.5846211499804018,
#  0.8742213395135796,
#  0.39585020058958387,
#  0.8609501494179723,
#  0.4309739626865165,
#  0.8828474622220712,
#  0.3723401544124311,
#  0.841330669768409,
#  0.48057614595161763,
#  0.8986417700180658,
#  0.32790506110870876,
#  0.7933799952288099,
#  0.5901414422383566,
#  0.8707482734082804,
#  0.4051645839532042,
#  0.8676224779076321,
#  0.41347336945338903,
#  0.8730473119425012,
#  0.3990085309889072,
#  0.8632826034731335,
#  0.4248927000496155,
#  0.8796920165789868,
#  0.3810023011662568,
#  0.8490223716201856,
#  0.46146018279103596,
#  0.8946528569621988,
#  0.33929684096966745,
#  0.8070281808396179,
#  0.5606413062131336,
#  0.886761475130754,
#  0.3614960208768594,
#  0.8309399319614039,
#  0.5057235411601728,
#  0.8998820678757161,
#  0.3243395944491882,
#  0.7889163189182075,
#  0.5994984983859095,
#  0.864360175748217,
#  0.42206998438342236,
#  0.8781368855975998,
#  0.38524498470197166,
#  0.8525926312702173,
#  0.45244237094620043,
#  0.8918577789076123,
#  0.3472109319945342,
#  0.815959802512876,
#  0.5406098515056877,
#  0.8940630238584696,
#  0.34097159961906925,
#  0.8089558843402166,
#  0.556366541513597,
#  0.8885621267920655,
#  0.35647010504217663,
#  0.8258370093122264,
#  0.5177888761048708,
#  0.8988608011929321,
#  0.32727622057823624,
#  0.7925993856801429,
#  0.5917881581985708,
#  0.8696697624522509,
#  0.40803936022258697,
#  0.8695556666342241,
#  0.40834299333072316,
#  0.8697563752623413,
#  0.40780880263027675,
#  0.8694028192591322,
#  0.40874960564425766,
#  0.8700241159077174,
#  0.40709575312816354,
#  0.8689276832874367,
#  0.41001251221499313,
#  0.8708481073517157,
#  0.4048980525851413,
#  0.8674402305524451,
#  0.4139556370976375,
#  0.8733469234058157,
#  0.39820346922028327,
#  0.8626948787563712,
#  0.42642872972604434,
#  0.8805141654849957,
#  0.37875229151492623,
#  0.847076375473627,
#  0.4663367625171236,
#  0.8959204311918174,
#  0.3356892437935874,
#  0.8028071114215566,
#  0.5699082717811189,
#  0.882406200731678,
#  0.373555791511069,
#  0.8424427037025879,
#  0.4778387808511018,
#  0.8982319693170043,
#  0.3290806750100419,
#  0.7948317036419176,
#  0.5870673594993762,
#  0.8727093896753031,
#  0.3999157590523071,
#  0.8639393209701269,
#  0.4231734143464906,
#  0.8787516326525664,
#  0.3835699227468555,
#  0.8511985335989766,
#  0.4559745239925427,
#  0.8930223268643405,
#  0.3439204221101023,
#  0.812300995316561,
#  0.5488851179674273,
#  0.8913968828687187,
#  0.34851052829034196,
#  0.8173833838600634,
#  0.5373640355383285,
#  0.8949741438538459,
#  0.33838353247291725,
#  0.8059684227266427,
#  0.5629799674590137,
#  0.8857206853159018,
#  0.3643903905099519,
#  0.8337961217302441,
#  0.4988885368242531,
#  0.8999955527385923,
#  0.32401280804165283,
#  0.7885026297598171,
#  0.6003584374380115,
#  0.8637414625260027,
#  0.4236917343820005,
#  0.8790373749541422,
#  0.3827904061963427,
#  0.8505428800333739,
#  0.4576308813284676,
#  0.8935374880187915,
#  0.34246168388589426,
#  0.8106540442413556,
#  0.5525786332673637,
#  0.8900477543654498,
#  0.3523058975320911,
#  0.8214712275463159,
#  0.5279624994955133,
#  0.8971851550390683,
#  0.3320782294197287,
#  0.7984882042746723,
#  0.5792572508719734,
#  0.8773858374631816,
#  0.38728774685596723,
#  0.8542654127683037,
#  0.44818566233797225,
#  0.8903349878855232,
#  0.35149895003667037,
#  0.8206107773752392,
#  0.5299514259510412,
#  0.8967704835005974,
#  0.33326346032172777,
#  0.7999161348100176,
#  0.5761811234902298,
#  0.879107171125559,
#  0.38259991008423394,
#  0.8503819879959723,
#  0.45803686495676516,
#  0.8936607430704355,
#  0.34211238971483715,
#  0.810257409066386,
#  0.5534652244298877,
#  0.8897092911959823,
#  0.3532560060798903,
#  0.8224783208941493,
#  0.5256278371918442,
#  0.897635570259126,
#  0.33078943175291886,
#  0.7969240209365996,
#  0.5826100528470303,
#  0.8754320850069991,
#  0.3925826983702707,
#  0.8584614839181159,
#  0.4374193123700003,
#  0.885901167128723,
#  0.3638890411512818,
#  0.833305704772617,
#  0.5000663057977047,
#  0.8999999841727483,
#  0.324000045582484,
#  0.7884864577621162,
#  0.6003920292763202,
#  0.8637171856480169,
#  0.4237553119114296,
#  0.8790722911377957,
#  0.38269511312955207,
#  0.8504624286587211,
#  0.4578339099550709,
#  0.8935992750611625,
#  0.34228659841677833,
#  0.810455338659778,
#  0.5530229377115131,
#  0.8898788450751876,
#  0.35278015018621645,
#  0.8219747369549052]
