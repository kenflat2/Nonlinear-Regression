# %%
import numpy as np
import numpy.linalg as la
import pandas as pd
import matplotlib.pyplot as plt
import numpy.random as rand
from EDMtoolkit import *
from mpl_toolkits.mplot3d import Axes3D

# %matplotlib notebook
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
filename = "baltic_sea_mesocosm_transformed.csv"

df = pd.read_csv(filename, encoding="utf-8", na_filter=False)
table = df.to_numpy()

# %%
for i in range(4):
    fig, ax = plt.subplots(1,figsize=(8,4))
    ax.set_title(df.columns[i+1])
    ax.plot(table[:,0],table[:,i+1])
    ax.set_ylabel("scaled abundance")
    ax.set_xlabel("days")
    plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">

# %%
pico_stationary_period = table[375:600,4]

# %%
t = np.linspace(0,1,num=len(table[:,0]))
# t = np.linspace(0,1,num=len(pico_stationary_period))

# %%
delayEmbed(table[:,1], 1, 12, 1)[0].shape[0]
# Out:
# 781

# %%
delta_agg, r_sqrd, ns_area = get_delta_agg(table[:,2], 12, t=t, tau=1, horizon=1, return_forecast_skill=True)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="640">

# %%
delta_agg
# Out:
# 4.706746402580091

# %%
ns_area
# Out:
# 88.45750172494314

# %%
table[-length,0]/np.sqrt(delta_agg) / 365
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-b1571db73f9f> in <module>
# ----> 1 table[-length,0]/np.sqrt(delta_agg) / 365
#
# NameError: name 'length' is not defined

# %%
table[-1,0]/(365*np.sqrt(4.003))
# Out:
# 3.6377456900904335

# %%
r_sqrd
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-4a0b8fb8f2f6> in <module>
# ----> 1 r_sqrd
#
# NameError: name 'r_sqrd' is not defined

# %%
index = 1

# %%
poincare2d(table[:,index])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
poincare2d(table[:,index], step=2)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
poincare2d(table[:,index], step=3)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
table[:,0]
# Out:
# array([   0.  ,    3.35,    6.7 ,   10.05,   13.4 ,   16.75,   20.1 ,
#          23.45,   26.8 ,   30.15,   33.5 ,   36.85,   40.2 ,   43.55,
#          46.9 ,   50.25,   53.6 ,   56.95,   60.3 ,   63.65,   67.  ,
#          70.35,   73.7 ,   77.05,   80.4 ,   83.75,   87.1 ,   90.45,
#          93.8 ,   97.15,  100.5 ,  103.85,  107.2 ,  110.55,  113.9 ,
#         117.25,  120.6 ,  123.95,  127.3 ,  130.65,  134.  ,  137.35,
#         140.7 ,  144.05,  147.4 ,  150.75,  154.1 ,  157.45,  160.8 ,
#         164.15,  167.5 ,  170.85,  174.2 ,  177.55,  180.9 ,  184.25,
#         187.6 ,  190.95,  194.3 ,  197.65,  201.  ,  204.35,  207.7 ,
#         211.05,  214.4 ,  217.75,  221.1 ,  224.45,  227.8 ,  231.15,
#         234.5 ,  237.85,  241.2 ,  244.55,  247.9 ,  251.25,  254.6 ,
#         257.95,  261.3 ,  264.65,  268.  ,  271.35,  274.7 ,  278.05,
#         281.4 ,  284.75,  288.1 ,  291.45,  294.8 ,  298.15,  301.5 ,
#         304.85,  308.2 ,  311.55,  314.9 ,  318.25,  321.6 ,  324.95,
#         328.3 ,  331.65,  335.  ,  338.35,  341.7 ,  345.05,  348.4 ,
#         351.75,  355.1 ,  358.45,  361.8 ,  365.15,  368.5 ,  371.85,
#         375.2 ,  378.55,  381.9 ,  385.25,  388.6 ,  391.95,  395.3 ,
#         398.65,  402.  ,  405.35,  408.7 ,  412.05,  415.4 ,  418.75,
#         422.1 ,  425.45,  428.8 ,  432.15,  435.5 ,  438.85,  442.2 ,
#         445.55,  448.9 ,  452.25,  455.6 ,  458.95,  462.3 ,  465.65,
#         469.  ,  472.35,  475.7 ,  479.05,  482.4 ,  485.75,  489.1 ,
#         492.45,  495.8 ,  499.15,  502.5 ,  505.85,  509.2 ,  512.55,
#         515.9 ,  519.25,  522.6 ,  525.95,  529.3 ,  532.65,  536.  ,
#         539.35,  542.7 ,  546.05,  549.4 ,  552.75,  556.1 ,  559.45,
#         562.8 ,  566.15,  569.5 ,  572.85,  576.2 ,  579.55,  582.9 ,
#         586.25,  589.6 ,  592.95,  596.3 ,  599.65,  603.  ,  606.35,
#         609.7 ,  613.05,  616.4 ,  619.75,  623.1 ,  626.45,  629.8 ,
#         633.15,  636.5 ,  639.85,  643.2 ,  646.55,  649.9 ,  653.25,
#         656.6 ,  659.95,  663.3 ,  666.65,  670.  ,  673.35,  676.7 ,
#         680.05,  683.4 ,  686.75,  690.1 ,  693.45,  696.8 ,  700.15,
#         703.5 ,  706.85,  710.2 ,  713.55,  716.9 ,  720.25,  723.6 ,
#         726.95,  730.3 ,  733.65,  737.  ,  740.35,  743.7 ,  747.05,
#         750.4 ,  753.75,  757.1 ,  760.45,  763.8 ,  767.15,  770.5 ,
#         773.85,  777.2 ,  780.55,  783.9 ,  787.25,  790.6 ,  793.95,
#         797.3 ,  800.65,  804.  ,  807.35,  810.7 ,  814.05,  817.4 ,
#         820.75,  824.1 ,  827.45,  830.8 ,  834.15,  837.5 ,  840.85,
#         844.2 ,  847.55,  850.9 ,  854.25,  857.6 ,  860.95,  864.3 ,
#         867.65,  871.  ,  874.35,  877.7 ,  881.05,  884.4 ,  887.75,
#         891.1 ,  894.45,  897.8 ,  901.15,  904.5 ,  907.85,  911.2 ,
#         914.55,  917.9 ,  921.25,  924.6 ,  927.95,  931.3 ,  934.65,
#         938.  ,  941.35,  944.7 ,  948.05,  951.4 ,  954.75,  958.1 ,
#         961.45,  964.8 ,  968.15,  971.5 ,  974.85,  978.2 ,  981.55,
#         984.9 ,  988.25,  991.6 ,  994.95,  998.3 , 1001.65, 1005.  ,
#        1008.35, 1011.7 , 1015.05, 1018.4 , 1021.75, 1025.1 , 1028.45,
#        1031.8 , 1035.15, 1038.5 , 1041.85, 1045.2 , 1048.55, 1051.9 ,
#        1055.25, 1058.6 , 1061.95, 1065.3 , 1068.65, 1072.  , 1075.35,
#        1078.7 , 1082.05, 1085.4 , 1088.75, 1092.1 , 1095.45, 1098.8 ,
#        1102.15, 1105.5 , 1108.85, 1112.2 , 1115.55, 1118.9 , 1122.25,
#        1125.6 , 1128.95, 1132.3 , 1135.65, 1139.  , 1142.35, 1145.7 ,
#        1149.05, 1152.4 , 1155.75, 1159.1 , 1162.45, 1165.8 , 1169.15,
#        1172.5 , 1175.85, 1179.2 , 1182.55, 1185.9 , 1189.25, 1192.6 ,
#        1195.95, 1199.3 , 1202.65, 1206.  , 1209.35, 1212.7 , 1216.05,
#        1219.4 , 1222.75, 1226.1 , 1229.45, 1232.8 , 1236.15, 1239.5 ,
#        1242.85, 1246.2 , 1249.55, 1252.9 , 1256.25, 1259.6 , 1262.95,
#        1266.3 , 1269.65, 1273.  , 1276.35, 1279.7 , 1283.05, 1286.4 ,
#        1289.75, 1293.1 , 1296.45, 1299.8 , 1303.15, 1306.5 , 1309.85,
#        1313.2 , 1316.55, 1319.9 , 1323.25, 1326.6 , 1329.95, 1333.3 ,
#        1336.65, 1340.  , 1343.35, 1346.7 , 1350.05, 1353.4 , 1356.75,
#        1360.1 , 1363.45, 1366.8 , 1370.15, 1373.5 , 1376.85, 1380.2 ,
#        1383.55, 1386.9 , 1390.25, 1393.6 , 1396.95, 1400.3 , 1403.65,
#        1407.  , 1410.35, 1413.7 , 1417.05, 1420.4 , 1423.75, 1427.1 ,
#        1430.45, 1433.8 , 1437.15, 1440.5 , 1443.85, 1447.2 , 1450.55,
#        1453.9 , 1457.25, 1460.6 , 1463.95, 1467.3 , 1470.65, 1474.  ,
#        1477.35, 1480.7 , 1484.05, 1487.4 , 1490.75, 1494.1 , 1497.45,
#        1500.8 , 1504.15, 1507.5 , 1510.85, 1514.2 , 1517.55, 1520.9 ,
#        1524.25, 1527.6 , 1530.95, 1534.3 , 1537.65, 1541.  , 1544.35,
#        1547.7 , 1551.05, 1554.4 , 1557.75, 1561.1 , 1564.45, 1567.8 ,
#        1571.15, 1574.5 , 1577.85, 1581.2 , 1584.55, 1587.9 , 1591.25,
#        1594.6 , 1597.95, 1601.3 , 1604.65, 1608.  , 1611.35, 1614.7 ,
#        1618.05, 1621.4 , 1624.75, 1628.1 , 1631.45, 1634.8 , 1638.15,
#        1641.5 , 1644.85, 1648.2 , 1651.55, 1654.9 , 1658.25, 1661.6 ,
#        1664.95, 1668.3 , 1671.65, 1675.  , 1678.35, 1681.7 , 1685.05,
#        1688.4 , 1691.75, 1695.1 , 1698.45, 1701.8 , 1705.15, 1708.5 ,
#        1711.85, 1715.2 , 1718.55, 1721.9 , 1725.25, 1728.6 , 1731.95,
#        1735.3 , 1738.65, 1742.  , 1745.35, 1748.7 , 1752.05, 1755.4 ,
#        1758.75, 1762.1 , 1765.45, 1768.8 , 1772.15, 1775.5 , 1778.85,
#        1782.2 , 1785.55, 1788.9 , 1792.25, 1795.6 , 1798.95, 1802.3 ,
#        1805.65, 1809.  , 1812.35, 1815.7 , 1819.05, 1822.4 , 1825.75,
#        1829.1 , 1832.45, 1835.8 , 1839.15, 1842.5 , 1845.85, 1849.2 ,
#        1852.55, 1855.9 , 1859.25, 1862.6 , 1865.95, 1869.3 , 1872.65,
#        1876.  , 1879.35, 1882.7 , 1886.05, 1889.4 , 1892.75, 1896.1 ,
#        1899.45, 1902.8 , 1906.15, 1909.5 , 1912.85, 1916.2 , 1919.55,
#        1922.9 , 1926.25, 1929.6 , 1932.95, 1936.3 , 1939.65, 1943.  ,
#        1946.35, 1949.7 , 1953.05, 1956.4 , 1959.75, 1963.1 , 1966.45,
#        1969.8 , 1973.15, 1976.5 , 1979.85, 1983.2 , 1986.55, 1989.9 ,
#        1993.25, 1996.6 , 1999.95, 2003.3 , 2006.65, 2010.  , 2013.35,
#        2016.7 , 2020.05, 2023.4 , 2026.75, 2030.1 , 2033.45, 2036.8 ,
#        2040.15, 2043.5 , 2046.85, 2050.2 , 2053.55, 2056.9 , 2060.25,
#        2063.6 , 2066.95, 2070.3 , 2073.65, 2077.  , 2080.35, 2083.7 ,
#        2087.05, 2090.4 , 2093.75, 2097.1 , 2100.45, 2103.8 , 2107.15,
#        2110.5 , 2113.85, 2117.2 , 2120.55, 2123.9 , 2127.25, 2130.6 ,
#        2133.95, 2137.3 , 2140.65, 2144.  , 2147.35, 2150.7 , 2154.05,
#        2157.4 , 2160.75, 2164.1 , 2167.45, 2170.8 , 2174.15, 2177.5 ,
#        2180.85, 2184.2 , 2187.55, 2190.9 , 2194.25, 2197.6 , 2200.95,
#        2204.3 , 2207.65, 2211.  , 2214.35, 2217.7 , 2221.05, 2224.4 ,
#        2227.75, 2231.1 , 2234.45, 2237.8 , 2241.15, 2244.5 , 2247.85,
#        2251.2 , 2254.55, 2257.9 , 2261.25, 2264.6 , 2267.95, 2271.3 ,
#        2274.65, 2278.  , 2281.35, 2284.7 , 2288.05, 2291.4 , 2294.75,
#        2298.1 , 2301.45, 2304.8 , 2308.15, 2311.5 , 2314.85, 2318.2 ,
#        2321.55, 2324.9 , 2328.25, 2331.6 , 2334.95, 2338.3 , 2341.65,
#        2345.  , 2348.35, 2351.7 , 2355.05, 2358.4 , 2361.75, 2365.1 ,
#        2368.45, 2371.8 , 2375.15, 2378.5 , 2381.85, 2385.2 , 2388.55,
#        2391.9 , 2395.25, 2398.6 , 2401.95, 2405.3 , 2408.65, 2412.  ,
#        2415.35, 2418.7 , 2422.05, 2425.4 , 2428.75, 2432.1 , 2435.45,
#        2438.8 , 2442.15, 2445.5 , 2448.85, 2452.2 , 2455.55, 2458.9 ,
#        2462.25, 2465.6 , 2468.95, 2472.3 , 2475.65, 2479.  , 2482.35,
#        2485.7 , 2489.05, 2492.4 , 2495.75, 2499.1 , 2502.45, 2505.8 ,
#        2509.15, 2512.5 , 2515.85, 2519.2 , 2522.55, 2525.9 , 2529.25,
#        2532.6 , 2535.95, 2539.3 , 2542.65, 2546.  , 2549.35, 2552.7 ,
#        2556.05, 2559.4 , 2562.75, 2566.1 , 2569.45, 2572.8 , 2576.15,
#        2579.5 , 2582.85, 2586.2 , 2589.55, 2592.9 , 2596.25, 2599.6 ,
#        2602.95, 2606.3 , 2609.65, 2613.  , 2616.35, 2619.7 , 2623.05,
#        2626.4 , 2629.75, 2633.1 , 2636.45, 2639.8 , 2643.15, 2646.5 ,
#        2649.85, 2653.2 , 2656.55])

# %%
poincare3d(table[:,index], step=2, scatter=False)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
poincare2d(table[:,index], step=5)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig = plt.figure(10)
ax = fig.gca(projection="3d")
ax.plot(table[6:,1],table[3:-3,1],table[:-6,1])
ax.set_xlabel("Calanoids")
ax.set_ylabel("Rotifers")
ax.set_zlabel("Nanophytoplankton")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
